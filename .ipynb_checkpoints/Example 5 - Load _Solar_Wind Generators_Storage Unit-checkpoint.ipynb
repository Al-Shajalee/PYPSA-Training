# %% [markdown]
# <span style="color: red; font-size: 2em; font-weight: bold;">Example 5: Solar_Wind Generator+Storage Unit - Load </span>

# %% [markdown]
# Network Connections:
# ![image-11.png](attachment:image-11.png)

# %%
# Example 6: Solar_Wind Generator+Storage Unit - Load (one day)
import pypsa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create the network
network = pypsa.Network()

# Add Buses
network.add("Bus", "bus1", carrier="DC")  # DC side (solar and wind generators to inverter)
network.add("Bus", "bus2", carrier="AC")  # AC side (inverter to load)

# Define time steps for the simulation
hours = pd.date_range("2023-01-01 00:00", "2023-01-01 23:00", freq="H")
network.set_snapshots(hours)


# Generate solar profile
solar_profile = pd.Series(0.5 * (1 + np.sin(2 * np.pi * (hours.hour - 6) / 24)), index=hours)  # Solar profile peaks at midday

# Apply a moving average to smooth the solar generation slightly (optional)
solar_profile_smooth = solar_profile.rolling(window=6, min_periods=1).mean()

# Add Solar Generator
p_nom_solar = 100  # Nominal power (MW)
network.add("Generator", "Solar Generator", bus="bus1", p_nom=p_nom_solar, p_max_pu=solar_profile_smooth, carrier="solar")



# Generate a smoother wind profile using larger variability
np.random.seed(42)  # For reproducibility
base_wind_speed = 0.6  # Average capacity factor (40%)
variability = 0.05  # Reduced variability for even smoother profile
wind_profile = pd.Series(
    base_wind_speed + variability * np.random.randn(len(hours)),
    index=hours
).clip(lower=0, upper=1)  # Ensure the values are between 0 and 1

# Apply a stronger moving average (window size = 6) for smoother profile
wind_profile_smooth = wind_profile.rolling(window=6, min_periods=1).mean()

# Add Wind Generator
p_nom_wind = 100  # Nominal power (MW)
network.add("Generator", "Wind Generator", bus="bus1", p_nom=p_nom_wind, p_max_pu=wind_profile_smooth, carrier="wind")


# Add Inverter (as a link)
inverter_efficiency = 0.95
network.add("Link", "Inverter", bus0="bus1", bus1="bus2", p_nom=p_nom_solar * 2, efficiency=inverter_efficiency, carrier="inverter")

# Define constant load demand
p_load = 110  # Load demand in MW
load_demand = pd.Series(p_load, index=network.snapshots)  # Constant across all snapshots

# Add Load
network.add("Load", "Load", bus="bus2", p_set=load_demand)

# Add Storage Unit
network.add(
    "StorageUnit",
    "Battery Storage",
    bus="bus1",
    p_nom=200,  # Maximum charging/discharging power (MW)
    max_hours=4,  # Max energy storage in hours
    efficiency_store=0.9,  # Charging efficiency
    efficiency_dispatch=0.9,  # Discharging efficiency
    state_of_charge_initial=400,  # Initial state of charge (MWh)
    carrier="battery",
)

# Solve the network using linear optimal power flow
network.lopf(network.snapshots)

# Extract results
wind_generation = wind_profile_smooth * p_nom_wind * inverter_efficiency  # Wind generation after inverter
solar_generation = solar_profile_smooth * p_nom_solar * inverter_efficiency  # Solar generation after inverter
storage_dispatch = network.storage_units_t.p["Battery Storage"]  # Charging (negative) and discharging (positive)
storage_charging = storage_dispatch.clip(upper=0)  # Charging (negative values)
storage_discharging = storage_dispatch.clip(lower=0)  # Discharging (positive values)
total_generation = wind_generation + solar_generation  # Total generation from wind + solar
total_to_load = total_generation + storage_dispatch  # Combined wind, solar, and storage contribution to load

# Plot 1: Wind and Solar Generation Profile
plt.figure(figsize=(12, 6))
plt.plot(hours, wind_generation, label="Wind Generation (MW)", color="green", linewidth=2)
plt.plot(hours, solar_generation, label="Solar Generation (MW)", color="orange", linewidth=2)
plt.title("Wind and Solar Generation Profile", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Power (MW)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# Plot 2: Storage Activity
plt.figure(figsize=(12, 6))
plt.bar(hours, storage_charging, label="Storage Charging (MW)", color="red", alpha=0.6, width=0.03)
plt.bar(hours, storage_discharging, label="Storage Discharging (MW)", color="blue", alpha=0.6, width=0.03)
plt.title("Storage Charging and Discharging", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Power (MW)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# Plot 3: Total Contribution to Load (Wind + Solar + Storage)
plt.figure(figsize=(12, 6))
plt.plot(hours, load_demand, label="Load Demand (MW)", color="black", linestyle="--", linewidth=2)
plt.plot(hours, total_generation, label="Total Generation (Wind + Solar) (MW)", color="purple", linewidth=2)
plt.plot(hours, total_to_load, label="Wind + Solar + Storage Contribution to Load (MW)", color="orange", linestyle="-.", linewidth=2)
plt.fill_between(hours, total_to_load, load_demand, where=(total_to_load < load_demand), interpolate=True, color="red", alpha=0.3, label="Deficit")
plt.fill_between(hours, total_to_load, load_demand, where=(total_to_load >= load_demand), interpolate=True, color="green", alpha=0.3, label="Surplus")
plt.title("Wind, Solar, and Storage Contribution to Load", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Power (MW)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# INFO:pypsa.linopf:Prepare linear problem
# INFO:pypsa.linopf:Total preparation time: 0.14s
# INFO:pypsa.linopf:Solve linear problem using Glpk solver
# INFO:pypsa.linopf:Optimization successful. Objective value: 0.00e+00

# %% [markdown]
# <span style="color: red; font-size: 2em; font-weight: bold;">Step by step code</span>

# %% [markdown]
# # Step 1: Setting Up the Environment

# %% [markdown]
# ## Install PyPSA

# %%
#!pip install pypsa

# %%
# Import pypsa 
import pypsa

# %% [markdown]
# ## Additional Libraries
# PyPSA may require other libraries for plotting and numerical operations:

# %%
# pip install numpy pandas matplotlib networkx

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Creating Your Network:

# %% [markdown]
# ## Creating the Network

# %%
# Create an empty network
network = pypsa.Network()

# %% [markdown]
# Network: Represents the electrical network.

# %% [markdown]
# ## Add buses

# %%
# Add 2 buses
network.add("Bus", "bus1", carrier="DC")  # DC side (solar and wind generators to inverter)
network.add("Bus", "bus2", carrier="AC")  # AC side (inverter to load)

network.buses
# Out:
# attribute  v_nom type    x    y carrier unit  v_mag_pu_set  v_mag_pu_min  \
# Bus
# bus1         1.0       0.0  0.0      DC                1.0           0.0
# bus2         1.0       0.0  0.0      AC                1.0           0.0
#
# attribute  v_mag_pu_max control sub_network
# Bus
# bus1                inf      PQ
# bus2                inf      PQ

# %% [markdown]
# Bus: A bus represents a point in the system where power is injected or consumed. It’s where all electrical components (load, generator) connect.
#
# v_nom: This is the nominal voltage of the bus. For simplicity, we set it to 20 kV.

# %% [markdown]
# ## Define time steps for the simulation

# %%
# Define time steps for the simulation
hours = pd.date_range("2023-01-01 00:00", "2023-01-01 23:00", freq="H")
network.set_snapshots(hours)
hours
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00',
#                '2023-01-01 02:00:00', '2023-01-01 03:00:00',
#                '2023-01-01 04:00:00', '2023-01-01 05:00:00',
#                '2023-01-01 06:00:00', '2023-01-01 07:00:00',
#                '2023-01-01 08:00:00', '2023-01-01 09:00:00',
#                '2023-01-01 10:00:00', '2023-01-01 11:00:00',
#                '2023-01-01 12:00:00', '2023-01-01 13:00:00',
#                '2023-01-01 14:00:00', '2023-01-01 15:00:00',
#                '2023-01-01 16:00:00', '2023-01-01 17:00:00',
#                '2023-01-01 18:00:00', '2023-01-01 19:00:00',
#                '2023-01-01 20:00:00', '2023-01-01 21:00:00',
#                '2023-01-01 22:00:00', '2023-01-01 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# ## Add Generators:

# %% [markdown]
# ### Add a Solar Generator

# %%
# Generate solar profile
solar_profile = pd.Series(0.5 * (1 + np.sin(2 * np.pi * (hours.hour - 6) / 24)), index=hours)  # Solar profile peaks at midday

# Apply a moving average to smooth the solar generation slightly (optional)
solar_profile_smooth = solar_profile.rolling(window=6, min_periods=1).mean()

solar_profile_smooth
# Out:
# 2023-01-01 00:00:00    0.000000
# 2023-01-01 01:00:00    0.008519
# 2023-01-01 02:00:00    0.028008
# 2023-01-01 03:00:00    0.057618
# 2023-01-01 04:00:00    0.096094
# 2023-01-01 05:00:00    0.141844
# 2023-01-01 06:00:00    0.225177
# 2023-01-01 07:00:00    0.327239
# 2023-01-01 08:00:00    0.441074
# 2023-01-01 09:00:00    0.558926
# 2023-01-01 10:00:00    0.672761
# 2023-01-01 11:00:00    0.774823
# 2023-01-01 12:00:00    0.858156
# 2023-01-01 13:00:00    0.917082
# 2023-01-01 14:00:00    0.947584
# 2023-01-01 15:00:00    0.947584
# 2023-01-01 16:00:00    0.917082
# 2023-01-01 17:00:00    0.858156
# 2023-01-01 18:00:00    0.774823
# 2023-01-01 19:00:00    0.672761
# 2023-01-01 20:00:00    0.558926
# 2023-01-01 21:00:00    0.441074
# 2023-01-01 22:00:00    0.327239
# 2023-01-01 23:00:00    0.225177
# Freq: H, dtype: float64

# %%
# Add the solar generator to Bus 1 
p_nom_solar = 100  # Nominal power (MW)
network.add("Generator", 
            "Solar Generator", 
            bus="bus1", 
            p_nom=p_nom_solar, 
            p_max_pu=solar_profile_smooth, 
            carrier="solar")


# p_max_pu=wind_profile(%)*p_nom

# %% [markdown]
# ### Add a Wind Generator

# %%
# Generate a smoother wind profile using larger variability
np.random.seed(42)  # For reproducibility
base_wind_speed = 0.6  # Average capacity factor (40%)
variability = 0.05  # Reduced variability for even smoother profile
wind_profile = pd.Series(
    base_wind_speed + variability * np.random.randn(len(hours)),
    index=hours
).clip(lower=0, upper=1)  # Ensure the values are between 0 and 1

# Apply a stronger moving average (window size = 6) for smoother profile
wind_profile_smooth = wind_profile.rolling(window=6, min_periods=1).mean()
wind_profile_smooth
# Out:
# 2023-01-01 00:00:00    0.624836
# 2023-01-01 01:00:00    0.608961
# 2023-01-01 02:00:00    0.616769
# 2023-01-01 03:00:00    0.631615
# 2023-01-01 04:00:00    0.622950
# 2023-01-01 05:00:00    0.617174
# 2023-01-01 06:00:00    0.626195
# 2023-01-01 07:00:00    0.633742
# 2023-01-01 08:00:00    0.624433
# 2023-01-01 09:00:00    0.616262
# 2023-01-01 10:00:00    0.614351
# 2023-01-01 11:00:00    0.612422
# 2023-01-01 12:00:00    0.601278
# 2023-01-01 13:00:00    0.578939
# 2023-01-01 14:00:00    0.568476
# 2023-01-01 15:00:00    0.559269
# 2023-01-01 16:00:00    0.554691
# 2023-01-01 17:00:00    0.561191
# 2023-01-01 18:00:00    0.551608
# 2023-01-01 19:00:00    0.555782
# 2023-01-01 20:00:00    0.582370
# 2023-01-01 21:00:00    0.585175
# 2023-01-01 22:00:00    0.594178
# 2023-01-01 23:00:00    0.579686
# Freq: H, dtype: float64

# %%
# Add Wind Generator to Bus 1
p_nom_wind = 100  # Nominal power (MW)
network.add("Generator", 
            "Wind Generator", 
            bus="bus1", 
            p_nom=p_nom_wind, 
            p_max_pu=wind_profile_smooth, 
            carrier="wind")

# %% [markdown]
# ## Add Storage Unit

# %%
# Add Storage Unit
network.add(
    "StorageUnit",
    "Battery Storage",
    bus="bus1",
    p_nom=200,  # Maximum charging/discharging power (MW)
    max_hours=4,  # Max energy storage in hours
    efficiency_store=0.9,  # Charging efficiency
    efficiency_dispatch=0.9,  # Discharging efficiency
    state_of_charge_initial=400,  # Initial state of charge (MWh)
    carrier="battery",
)

# %% [markdown]
# ## Add Inverter (as a link)

# %%
# Add Inverter (as a link) between Bus 1 (DC) and Bus 2 (AC)
inverter_efficiency = 0.95
network.add("Link", 
            "Inverter", 
            bus0="bus1", 
            bus1="bus2", 
            p_nom=p_nom_solar * 2, 
            efficiency=inverter_efficiency, 
            carrier="inverter")

# %% [markdown]
#             bus0="bus1"  # DC input
#             bus1="bus2"  # AC output

# %% [markdown]
# ## Add a Load
# A load consumes power from the grid. Let’s add a load to Bus2 that will consume some power.

# %%
# Define constant load demand
p_load = 110  # Load demand in MW
load_demand = pd.Series(p_load, index=network.snapshots)  # Constant across all snapshots

# Add Load
network.add("Load", 
            "Load", 
            bus="bus2", 
            p_set=load_demand)

# %% [markdown]
# Load: Represents a power consumer.
#
# bus: The bus where the load is connected. # Connected to AC bus
#
# p_set: Constant load demand (MW)

# %% [markdown]
# # Step 3: Check results

# %%
# Print the network
print(network)
# Out:
# PyPSA Network
# Components:
#  - Bus: 2
#  - Generator: 2
#  - Link: 1
#  - Load: 1
#  - StorageUnit: 1
# Snapshots: 24

# %% [markdown]
# # Step 4: Solving the Network
# PyPSA includes tools for solving network power flows and optimization problems.

# %% [markdown]
# ## Power Flow Calculation
# After setting up the network, calculate the power flow:
# We will now solve the network to find the power flow, voltages at each bus, and the power transmitted through the lines.

# %%
# Solve the network using linear optimal power flow
network.lopf(network.snapshots)
# Out:
# INFO:pypsa.linopf:Prepare linear problem
# INFO:pypsa.linopf:Total preparation time: 0.14s
# INFO:pypsa.linopf:Solve linear problem using Glpk solver
# INFO:pypsa.linopf:Optimization successful. Objective value: 0.00e+00
# ('ok', 'optimal')

# %% [markdown]
# ## Extract results
#
# You can inspect the power flows on lines and outputs of generators:

# %%
# Extract results
wind_generation = wind_profile_smooth * p_nom_wind * inverter_efficiency  # Wind generation after inverter
solar_generation = solar_profile_smooth * p_nom_solar * inverter_efficiency  # Solar generation after inverter
storage_dispatch = network.storage_units_t.p["Battery Storage"]  # Charging (negative) and discharging (positive)
storage_charging = storage_dispatch.clip(upper=0)  # Charging (negative values)
storage_discharging = storage_dispatch.clip(lower=0)  # Discharging (positive values)
total_generation = wind_generation + solar_generation  # Total generation from wind + solar
total_to_load = total_generation + storage_dispatch  # Combined wind, solar, and storage contribution to load

# %% [markdown]
# # Power Visualization

# %%
# Plot 1: Wind and Solar Generation Profile
plt.figure(figsize=(12, 6))
plt.plot(hours, wind_generation, label="Wind Generation (MW)", color="green", linewidth=2)
plt.plot(hours, solar_generation, label="Solar Generation (MW)", color="orange", linewidth=2)
plt.title("Wind and Solar Generation Profile", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Power (MW)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# Plot 2: Storage Activity
plt.figure(figsize=(12, 6))
plt.bar(hours, storage_charging, label="Storage Charging (MW)", color="red", alpha=0.6, width=0.03)
plt.bar(hours, storage_discharging, label="Storage Discharging (MW)", color="blue", alpha=0.6, width=0.03)
plt.title("Storage Charging and Discharging", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Power (MW)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# Plot 3: Total Contribution to Load (Wind + Solar + Storage)
plt.figure(figsize=(12, 6))
plt.plot(hours, load_demand, label="Load Demand (MW)", color="black", linestyle="--", linewidth=2)
plt.plot(hours, total_generation, label="Total Generation (Wind + Solar) (MW)", color="purple", linewidth=2)
plt.plot(hours, total_to_load, label="Wind + Solar + Storage Contribution to Load (MW)", color="orange", linestyle="-.", linewidth=2)
plt.fill_between(hours, total_to_load, load_demand, where=(total_to_load < load_demand), interpolate=True, color="red", alpha=0.3, label="Deficit")
plt.fill_between(hours, total_to_load, load_demand, where=(total_to_load >= load_demand), interpolate=True, color="green", alpha=0.3, label="Surplus")
plt.title("Wind, Solar, and Storage Contribution to Load", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Power (MW)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
